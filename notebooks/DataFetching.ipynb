# %%
# %matplotlib inline
from osgeo import gdal, osr
import geopandas as gpd
import gdal
import sys
import matplotlib.pyplot as plt
import earthpy as et
import earthpy.spatial as es
import earthpy.plot as ep
import rasterio as rio
import numpy as np
import imageio
from rasterio.plot import show
import pandas as pd
import pathlib
import mapclassify as mc
import laspy
from rasterio import mask
import folium
from shapely.geometry import Point
from typing import Tuple
# sys.path.append('../scripts')
from point import CloudSubSampler

# %%
filename= '../Data/iowa.tif'

# %%
ds= gdal.Open(filename)
type(ds)
# Out:
# osgeo.gdal.Dataset

# %%
#print raster info
print("Width",ds.RasterXSize, "Height", ds.RasterYSize)
# Out:
# Width 1499 Height 1493

# %%
print(ds.GetDescription)
# Out:
# <bound method MajorObject.GetDescription of <osgeo.gdal.Dataset; proxy of <Swig Object of type 'GDALDatasetShadow *' at 0x7f7aa877d780> >>

# %%
print('coordinate system',ds.GetProjection())
# Out:
# coordinate system PROJCS["NAD83 / UTM zone 15N",GEOGCS["NAD83",DATUM["North_American_Datum_1983",SPHEROID["GRS 1980",6378137,298.257222101,AUTHORITY["EPSG","7019"]],TOWGS84[0,0,0,0,0,0,0],AUTHORITY["EPSG","6269"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4269"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-93],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","26915"]]

# %%
print(ds.GetGeoTransform())
# Out:
# (446112.3908587211, 1.0, 0.0, 4654068.19273306, 0.0, -1.0)

# %%
#number of raster bands 
# here is telling that its a single band raster (either binary image, represented as 0 or 1 or grayscle image o to 255 or color map) 
print(ds.RasterCount)
# Out:
# 1

# %%
#raster band info
band1=ds.GetRasterBand(1)
print("Num data value", band1.GetNoDataValue())
# Out:
# Num data value -9999.0

# %%
print("min value", band1.GetMinimum())
# Out:
# min value None

# %%
print("max value", band1.GetMaximum())
# Out:
# max value None

# %%
rastArr= ds.GetRasterBand(1).ReadAsArray()
rastArr.shape
# Out:
# (1493, 1499)

# %%
rastArr
# Out:
# array([[-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        ...,
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.]])

# %%
print("metadata:",ds.GetMetadata())
# Out:
# metadata: {'AREA_OR_POINT': 'Area'}

# %%
print("metadata:",ds.GetMetadata("IMAGE_STRUCTURE"))
# Out:
# metadata: {'COMPRESSION': 'DEFLATE', 'INTERLEAVE': 'BAND'}

# %%
def plot_raster(rast_data, title=''):
    """
    Plots raster tif image both in log scale(+1) and original verion
    """
    fig, (axlog, axorg) = plt.subplots(1, 2, figsize=(14,7))
    im1 = axlog.imshow(np.log1p(rast_data)) # vmin=0, vmax=2.1)
#     im2 = axorg.imshow(rast_data)

    plt.title("{}".format(title), fontdict = {'fontsize': 15})  
    plt.axis('off')
    plt.colorbar(im1, fraction=0.03)

# %%
plt.imshow(rastArr)

# %%
data= rio.open(filename)
rast_ds=data.read(1)

# %%
count = rast_ds[rast_ds > 0].sum()

# %%
title = 'Log scaled (+1) and No Scale Raster plots'.format(count)
plot_raster(rast_ds, title)
# Out:
# <ipython-input-16-aaa0998cce4c>:6: RuntimeWarning: invalid value encountered in log1p
#   im1 = axlog.imshow(np.log1p(rast_data)) # vmin=0, vmax=2.1)
# <ipython-input-16-aaa0998cce4c>:11: MatplotlibDeprecationWarning: Starting from Matplotlib 3.6, colorbar() will steal space from the mappable's axes, rather than from the current axes, to place the colorbar.  To silence this warning, explicitly pass the 'ax' argument to colorbar().
#   plt.colorbar(im1, fraction=0.03)

# %%
from shapely.geometry import Polygon

MINX, MINY, MAXX, MAXY = [-93.756155, 41.918015, -93.747334, 41.921429]
polygon = Polygon(((MINX, MINY), (MINX, MAXY), (MAXX, MAXY), (MAXX, MINY), (MINX, MINY)))

# %%
# get shp from tif
def get_shp_from_tif(tif_path:str, shp_file_path:str) -> None:
    raster = rio.open(tif_path)
    df= gpd.GeoDataFrame([polygon], columns=["geometry"])
    df.set_crs(epsg=4326, inplace=True)
  # save to file
    df.to_file(shp_file_path)
    print('Saved..')

# %%
from shapely.geometry import box
get_shp_from_tif('../Data/iowa.tif', shp_file_path='../Data/combi.shp')
# Out:
# Saved..

# %%
usa_gdf = (gpd.GeoDataFrame.from_file('../Data/combi.shp'))
usa_gdf.shape
usa_gdf
# Out:
#    FID                                           geometry
# 0    0  POLYGON ((-93.75616 41.91801, -93.75616 41.921...

# %%
# plot the shapefile
plt.rcParams['figure.figsize'] = 10,5
usa_gdf.plot(color="gray", edgecolor="#2e3131", figsize=(10, 5))
plt.title('USA: regions')
# Out:
# Text(0.5, 1.0, 'USA: regions')

# %%
usa_gdf['area'] = usa_gdf.area
# Returns a GeoSeries of points for each geometric centroid.
usa_gdf['centroid'] = usa_gdf.centroid
# Returns a GeoSeries of geometries representing the point or smallest rectangular
# polygon (with sides parallel to the coordinate axes) that contains each object.
usa_gdf['envelope'] = usa_gdf.envelope
# Out:
# <ipython-input-26-3d977b47793c>:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   usa_gdf['area'] = usa_gdf.area
# <ipython-input-26-3d977b47793c>:3: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   usa_gdf['centroid'] = usa_gdf.centroid

# %%
print(usa_gdf.crs)
# Out:
# epsg:4326

# %%
usa_gdf=usa_gdf.set_geometry('centroid')
usa_gdf.plot();

# %%
usa_gdf
# Out:
#    FID                                           geometry     area  \
# 0    0  POLYGON ((-93.75616 41.91801, -93.75616 41.921...  0.00003
#
#                      centroid  \
# 0  POINT (-93.75174 41.91972)
#
#                                             envelope
# 0  POLYGON ((-93.75616 41.91801, -93.74733 41.918...

# %%
usa_g = usa_gdf.drop(['centroid', 'envelope'], axis=1)

# %%
src = rio.open('../Data/iowa.tif')
plt.figure(figsize=(10, 6))
plt.imshow(src.read(1), cmap='pink')
plt.show()

# %%
fig, ax = plt.subplots(1, figsize=(12, 12))
show((src, 1), ax=ax, contour=True, contour_label_kws={})
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12, 8))
from rasterio.plot import show_hist
show_hist(
    src, bins=50, lw=0.0, stacked=False, alpha=0.3,
   histtype='stepfilled', title="Histogram of a raster")

# %%
fig, (axrgb, axhist) = plt.subplots(1, 2, figsize=(14,7))
show((src), cmap='Greys_r', contour=True, ax=axrgb)
show_hist(src, bins=50, histtype='stepfilled',
          lw=0.0, stacked=False, alpha=0.3, ax=axhist)
plt.show()

# %% [markdown]
# ## Terran visualization

# %%
def create_cloud_points(array):
    cloud_points = []
    for row in rastArr[0]:
        
        
        lst = row.tolist()#[-3:]
        cloud_points.append(lst)

    cloud_points = np.array(cloud_points)

    cloud_point = cloud_points
    return cloud_point

# %%
 def get_elevation_geodf(cloud_points) -> gpd.GeoDataFrame:
     
    """Calculates and returns a geopandas elevation dataframe from the cloud points generated before.

    Parameters
    ----------
    None

    Returns
    -------
    gpd.GeoDataFrame
    Geopandas Dataframe with Elevation and coordinate points referenced as Geometry points
    """
    cloud_points=cloud_points
    elevation = gpd.GeoDataFrame()
    elevations = []
    points = []
    for row in cloud_points:
        elevations.append(cloud_points[2])
        point = Point(cloud_points[0], cloud_points[1])
        points.append(point)

    elevation['elevation'] = elevations
    elevation['geometry'] = points
    elevation.set_crs(epsg=epsg, inplace=True)

    elevation_geodf = elevation

    return elelevation_geodf

# %%
def get_terrain_map(smarkersize: int = 10, fig_size: Tuple[int, int] = (15, 20)) -> plt:
    
    
    """Constructs a Terrain Map from the cloud points.

    Parameters
    ----------
    markersize : int, optional
    Marker size used when ploting the figure
    fig_size : Tuple[int, int], optional
    Size of the figure to be returned

    Returns
    -------
    plt
    Returns a Terrain Map constructed from the cloud points
    """
    get_elevation_geodf()

    elevation_geodf.plot(c='elevation', scheme="quantiles", cmap='terrain', legend=True,
    markersize=markersize,
    figsize=(fig_size[0], fig_size[1]),
    missing_kwds={
    "color": "lightgrey",
    "edgecolor": "red",
    "hatch": "///",
    "label": "Missing values"}
    )

    plt.title('Terrain Elevation Map')
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')

# %%
x=rastArr.astype(int)

# %%
y=create_cloud_points(x)

# %%
l=y[:4]

# %%
l
# Out:
# array([-9999., -9999., -9999., -9999.])

# %%
 epsg="4326"
elevation=get_elevation_geodf(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-448ff2f7e4de> in <module>
# ----> 1 elevation=get_elevation_geodf(y)
#
# <ipython-input-62-686cfaebdb8a> in get_elevation_geodf(cloud_points)
#      23    elevation['elevation'] = elevations
#      24    elevation['geometry'] = points
# ---> 25    elevation.set_crs(epsg=epsg, inplace=True)
#      26
#      27    elevation_geodf = elevation
#
# NameError: name 'epsg' is not defined
